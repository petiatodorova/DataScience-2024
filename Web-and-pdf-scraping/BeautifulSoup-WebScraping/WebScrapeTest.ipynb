# %%
from bs4 import BeautifulSoup
import requests

# %%
# URL of the web page
url = "https://www.crummy.com/software/BeautifulSoup/bs4/doc/"

# %%
result = requests.get(url)

# %%
doc = BeautifulSoup(result.text, "html")

# %%
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html data-content_root="./" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Beautiful Soup Documentation — Beautiful Soup 4.12.0 documentation
#   </title>
#   <link href="_static/pygments.css?v=fa44fd50" rel="stylesheet" type="text/css"/>
#   <link href="_static/classic.css?v=514cf933" rel="stylesheet" type="text/css"/>
#   <script src="_static/documentation_options.js?v=7155e95a">
#   </script>
#   <script src="_static/doctools.js?v=888ff710">
#   </script>
#   <script src="_static/sphinx_highlight.js?v=dc90522c">
#   </script>
#   <link href="genindex.html" rel="index" title="Index"/>
#   <link href="search.html" rel="search" title="Search"/>
#  </head>
#  <body>
#   <div aria-label="related navigation" class="related" role="navigation">
#    <h3>
#     Navigation
#    </h3>
#    <ul>
# ...
